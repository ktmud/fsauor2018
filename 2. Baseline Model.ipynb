# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import logging

logging.getLogger('jieba').setLevel(logging.WARN)
logging.getLogger('fgclassifier').setLevel(logging.INFO)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# This notebook shows how to use our baseline model.
# It also demonstrates how to test different feature models (i.e.,
# different ways of building the features) at the same time.
#
# We will use mostly the Google Translated English dataset for this
# demonstration purpose.

# %%
import config
from collections import defaultdict
from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation

from fgclassifier.features import FeaturePipeline, logger, SparseToDense 
from fgclassifier.utils import read_data

X, y = read_data('data/english.csv', flavor=None)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# feature models with dependency specs
fm_spec = {
   'count': CountVectorizer(ngram_range=(1, 4), min_df=0.001, stop_words='english'),
   'tfidf': ['count', TfidfTransformer],
   'lsa_200': ['tfidf', TruncatedSVD(n_components=200)],
   'lsa_500': ['tfidf', TruncatedSVD(n_components=500)],
   'lsa_1k': ['tfidf', TruncatedSVD(n_components=1000)],
#    'lda_count_100': ['count', LatentDirichletAllocation(n_components=100)],
#    'lda_tfidf_100': ['tfidf', LatentDirichletAllocation(n_components=100)],
    
    # small vocabulary (removed more stop words)
   'count_sv': CountVectorizer(ngram_range=(1, 5), min_df=0.02, max_df=0.99,
                               stop_words='english'),
   'tfidf_sv': ['count_sv', TfidfTransformer],
   'tfidf_sv_dense': ['tfidf_sv', SparseToDense()],
   'lsa_100_sv': ['tfidf_sv', TruncatedSVD(n_components=100)],
   'lsa_500_sv': ['tfidf_sv', TruncatedSVD(n_components=500)],
#    'lda_count_100_sv': ['count_sv', LatentDirichletAllocation(n_components=100)],
#    'lda_tfidf_100_sv': ['tfidf_sv', LatentDirichletAllocation(n_components=100)],
}
# Out:
# 2018-11-20 22:54:56,383 [INFO] Reading data/english.csv..

# %%
# Cache trained fetures, we make this cache object
# so different steps can reuse previously trained features
fm = defaultdict(dict)

# %%
for name in fm_spec.keys():
    logger.info(f'Building features for {name}...')
    model = FeaturePipeline(name, spec=fm_spec, cache=fm)
    model.fit_transform(X_train)
    model.transform(X_test)
# Out:
# 2018-11-20 22:55:02,996 [INFO] Building features for count...
# 2018-11-20 22:55:02,998 [INFO]   count: fit_transform use cache.
# 2018-11-20 22:55:02,999 [INFO]   count: transform use cache.
# 2018-11-20 22:55:03,001 [INFO] Building features for tfidf...
# 2018-11-20 22:55:03,002 [INFO]   tfidf: fit_transform use cache.
# 2018-11-20 22:55:03,003 [INFO]   tfidf: transform use cache.
# 2018-11-20 22:55:03,004 [INFO] Building features for lsa_200...
# 2018-11-20 22:55:03,006 [INFO]   lsa_200: fit_transform use cache.
# 2018-11-20 22:55:03,007 [INFO]   lsa_200: transform use cache.
# 2018-11-20 22:55:03,008 [INFO] Building features for lsa_500...
# 2018-11-20 22:55:03,010 [INFO]   tfidf: fit_transform use cache.
# 2018-11-20 22:55:12,918 [INFO]   tfidf: transform use cache.
# 2018-11-20 22:55:13,083 [INFO] Building features for lsa_1k...
# 2018-11-20 22:55:13,085 [INFO]   lsa_1k: fit_transform use cache.
# 2018-11-20 22:55:13,087 [INFO]   lsa_1k: transform use cache.
# 2018-11-20 22:55:13,091 [INFO] Building features for count_sv...
# 2018-11-20 22:55:13,094 [INFO]   count_sv: fit_transform use cache.
# 2018-11-20 22:55:13,096 [INFO]   count_sv: transform use cache.
# 2018-11-20 22:55:13,098 [INFO] Building features for tfidf_sv...
# 2018-11-20 22:55:13,100 [INFO]   tfidf_sv: fit_transform use cache.
# 2018-11-20 22:55:13,101 [INFO]   tfidf_sv: transform use cache.
# 2018-11-20 22:55:13,104 [INFO] Building features for tfidf_sv_dense...
# 2018-11-20 22:55:13,105 [INFO]   tfidf_sv: fit_transform use cache.
# 2018-11-20 22:55:13,123 [INFO]   tfidf_sv: transform use cache.
# 2018-11-20 22:55:13,133 [INFO] Building features for lsa_100_sv...
# 2018-11-20 22:55:13,139 [INFO]   lsa_100_sv: fit_transform use cache.
# 2018-11-20 22:55:13,140 [INFO]   lsa_100_sv: transform use cache.
# 2018-11-20 22:55:13,141 [INFO] Building features for lsa_500_sv...
# 2018-11-20 22:55:13,143 [INFO]   lsa_500_sv: fit_transform use cache.
# 2018-11-20 22:55:13,144 [INFO]   lsa_500_sv: transform use cache.

# %% [markdown]
# Exam the quality of the top terms:

# %%
from collections import Counter

print('Data Shape:', X_train.shape, X_test.shape)

for mn in ['count', 'count_sv']:
    model = fm[mn]['model'].named_steps[mn]
    x_train = fm[mn]['train']
    counts = np.sum(x_train, axis=0).flat
    counts = {k: counts[v] for k, v in model.vocabulary_.items()}
    print('\nmin_df: %.2f, max_df: %.2f, ngram_range: %s' % (
        model.min_df, model.max_df, model.ngram_range
    ))
    print('\nvocab size: %s\n' % len(model.vocabulary_))
    print('\n'.join([
        '%s \t %s' % (k, v)
        for k, v in Counter(counts).most_common()[:10]]))
# Out:
# Data Shape: (7500,) (2500,)
#
# min_df: 0.00, max_df: 1.00, ngram_range: (1, 4)
#
# vocab size: 18512
#
# good 	 17818
# taste 	 12112
# eat 	 11203
# time 	 6935
# delicious 	 6583
# store 	 6551
# like 	 6169
# people 	 5905
# dishes 	 5507
# really 	 5364
#
# min_df: 0.02, max_df: 0.99, ngram_range: (1, 5)
#
# vocab size: 945
#
# good 	 17818
# taste 	 12112
# eat 	 11203
# time 	 6935
# delicious 	 6583
# store 	 6551
# like 	 6169
# people 	 5905
# dishes 	 5507
# really 	 5364

# %%
fm['tfidf']['model'].named_steps
# Out:
# {'count': FeaturePipeline(cache={'model': FeaturePipeline(cache={...}, spec=None,
#          steps=[('count', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=0.001,
#          ...atrix of type '<class 'numpy.int64'>'
#  	with 287551 stored elements in Compressed Sparse Row format>},
#          spec=None,
#          steps=[('count', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=0.001,
#          ngram_range=(1, 4), preprocessor=None, stop_words='english',
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=None, vocabulary=None))]),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)}

# %% [markdown]
# ## The Very Basic TF-IDF + LDA classifier

# %%
from fgclassifier.baseline import Baseline
from fgclassifier.classifiers import LDA

# Linear Discriminant Analysis
model = Baseline(classifier=LDA)
model.fit(fm['lsa_1k']['train'], y_train)
model.score(fm['lsa_1k']['test'], y_test)
# Out:
# 2018-11-20 22:47:06,290 [INFO] [Validate]: F1 Scores
# 2018-11-20 22:47:06,297 [INFO]   location_traffic_convenience            	0.4290
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 22:47:06,301 [INFO]   location_distance_from_business_district	0.3449
# 2018-11-20 22:47:06,304 [INFO]   location_easy_to_find                   	0.3998
# 2018-11-20 22:47:06,308 [INFO]   service_wait_time                       	0.4152
# 2018-11-20 22:47:06,311 [INFO]   service_waiters_attitude                	0.5634
# 2018-11-20 22:47:06,315 [INFO]   service_parking_convenience             	0.4753
# 2018-11-20 22:47:06,318 [INFO]   service_serving_speed                   	0.4981
# 2018-11-20 22:47:06,322 [INFO]   price_level                             	0.5377
# 2018-11-20 22:47:06,326 [INFO]   price_cost_effective                    	0.4568
# 2018-11-20 22:47:06,334 [INFO]   price_discount                          	0.4942
# 2018-11-20 22:47:06,340 [INFO]   environment_decoration                  	0.4549
# 2018-11-20 22:47:06,343 [INFO]   environment_noise                       	0.5449
# 2018-11-20 22:47:06,347 [INFO]   environment_space                       	0.4774
# 2018-11-20 22:47:06,350 [INFO]   environment_cleaness                    	0.4780
# 2018-11-20 22:47:06,356 [INFO]   dish_portion                            	0.3856
# 2018-11-20 22:47:06,361 [INFO]   dish_taste                              	0.5141
# 2018-11-20 22:47:06,366 [INFO]   dish_look                               	0.3424
# 2018-11-20 22:47:06,369 [INFO]   dish_recommendation                     	0.3581
# 2018-11-20 22:47:06,373 [INFO]   others_overall_experience               	0.4631
# 2018-11-20 22:47:06,376 [INFO]   others_willing_to_consume_again         	0.4025
# 0.45177582066396765

# %% [markdown]
# ## Search for the Best Feature + Classifier Combination

# %%
# Run for all classifiers and feature builders
all_avg_scores, all_scores = defaultdict(dict), defaultdict(dict)

# %%
from fgclassifier.train import fm_cross_check

conf = {
    'fm_cache': fm,
    'y_train': y_train,
    'y_test': y_test,
    'results': {
        'avg': all_avg_scores,
        'all': all_scores
    }
}

# We'd only need to run the dummy models on one feature model,
# as they do not care about the features
# fm_cross_check(
#     ['tfidf'],
#     ['DummyStratified', 'DummyMostFrequent'], **conf)

# Naive Bayes models cannot handle negative values, so we pass
# in only tfidf features
fm_cross_check(
    [#'tfidf',
     'tfidf_sv'],
    [#'MultinomialNB',
    'ComplementNB'], **conf)

# All other models can run on many classifiers
results = fm_cross_check(
    [#'lsa_200', 'lsa_500', 'lsa_1k',
     # 'tfidf_sv_dense',
     'lsa_100_sv', 'lsa_500_sv',
    ],
    ['LDA', 'LinearSVC', 'Logistic', 'Ridge'], **conf)
# Out:
# 2018-11-20 23:00:24,326 [INFO] ======== Feature Model: tfidf_sv =========
# 2018-11-20 23:00:24,329 [INFO] Train for tfidf_sv -> ComplementNB...
# 2018-11-20 23:00:24,505 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:00:24,510 [INFO]   location_traffic_convenience            	0.3896
# 2018-11-20 23:00:24,514 [INFO]   location_distance_from_business_district	0.3193
# 2018-11-20 23:00:24,516 [INFO]   location_easy_to_find                   	0.3192
# 2018-11-20 23:00:24,519 [INFO]   service_wait_time                       	0.3564
# 2018-11-20 23:00:24,525 [INFO]   service_waiters_attitude                	0.4596
# 2018-11-20 23:00:24,533 [INFO]   service_parking_convenience             	0.2840
# 2018-11-20 23:00:24,537 [INFO]   service_serving_speed                   	0.4255
# 2018-11-20 23:00:24,541 [INFO]   price_level                             	0.4902
# 2018-11-20 23:00:24,547 [INFO]   price_cost_effective                    	0.4091
# 2018-11-20 23:00:24,552 [INFO]   price_discount                          	0.4705
# 2018-11-20 23:00:24,555 [INFO]   environment_decoration                  	0.3822
# 2018-11-20 23:00:24,558 [INFO]   environment_noise                       	0.4379
# 2018-11-20 23:00:24,561 [INFO]   environment_space                       	0.4428
# 2018-11-20 23:00:24,565 [INFO]   environment_cleaness                    	0.3822
# 2018-11-20 23:00:24,570 [INFO]   dish_portion                            	0.3580
# 2018-11-20 23:00:24,574 [INFO]   dish_taste                              	0.4802
# 2018-11-20 23:00:24,577 [INFO]   dish_look                               	0.3499
# 2018-11-20 23:00:24,579 [INFO]   dish_recommendation                     	0.3026
# 2018-11-20 23:00:24,581 [INFO]   others_overall_experience               	0.4236
# 2018-11-20 23:00:24,585 [INFO]   others_willing_to_consume_again         	0.3596
# 2018-11-20 23:00:24,587 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:24,588 [INFO] 【tfidf_sv -> ComplementNB】: 0.3921
# 2018-11-20 23:00:24,590 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:24,591 [INFO] ======== Feature Model: lsa_100_sv =========
# 2018-11-20 23:00:24,592 [INFO] Train for lsa_100_sv -> LDA...
# 2018-11-20 23:00:27,778 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:00:27,781 [INFO]   location_traffic_convenience            	0.4202
# 2018-11-20 23:00:27,783 [INFO]   location_distance_from_business_district	0.2677
# 2018-11-20 23:00:27,786 [INFO]   location_easy_to_find                   	0.2951
# 2018-11-20 23:00:27,789 [INFO]   service_wait_time                       	0.3427
# 2018-11-20 23:00:27,792 [INFO]   service_waiters_attitude                	0.4975
# 2018-11-20 23:00:27,795 [INFO]   service_parking_convenience             	0.3593
# 2018-11-20 23:00:27,799 [INFO]   service_serving_speed                   	0.4118
# 2018-11-20 23:00:27,801 [INFO]   price_level                             	0.4503
# 2018-11-20 23:00:27,805 [INFO]   price_cost_effective                    	0.3995
# 2018-11-20 23:00:27,811 [INFO]   price_discount                          	0.4430
# 2018-11-20 23:00:27,819 [INFO]   environment_decoration                  	0.3520
# 2018-11-20 23:00:27,821 [INFO]   environment_noise                       	0.3323
# 2018-11-20 23:00:27,824 [INFO]   environment_space                       	0.3615
# 2018-11-20 23:00:27,827 [INFO]   environment_cleaness                    	0.3393
# 2018-11-20 23:00:27,830 [INFO]   dish_portion                            	0.3180
# 2018-11-20 23:00:27,834 [INFO]   dish_taste                              	0.4671
# 2018-11-20 23:00:27,837 [INFO]   dish_look                               	0.2818
# 2018-11-20 23:00:27,842 [INFO]   dish_recommendation                     	0.3439
# 2018-11-20 23:00:27,852 [INFO]   others_overall_experience               	0.4156
# 2018-11-20 23:00:27,857 [INFO]   others_willing_to_consume_again         	0.3533
# 2018-11-20 23:00:27,858 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:27,859 [INFO] 【lsa_100_sv -> LDA】: 0.3726
# 2018-11-20 23:00:27,861 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:27,863 [INFO] Train for lsa_100_sv -> LinearSVC...
# 2018-11-20 23:00:37,028 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:00:37,031 [INFO]   location_traffic_convenience            	0.4222
# 2018-11-20 23:00:37,036 [INFO]   location_distance_from_business_district	0.2398
# 2018-11-20 23:00:37,040 [INFO]   location_easy_to_find                   	0.2700
# 2018-11-20 23:00:37,044 [INFO]   service_wait_time                       	0.2541
# 2018-11-20 23:00:37,046 [INFO]   service_waiters_attitude                	0.4873
# 2018-11-20 23:00:37,050 [INFO]   service_parking_convenience             	0.2819
# 2018-11-20 23:00:37,053 [INFO]   service_serving_speed                   	0.3390
# 2018-11-20 23:00:37,057 [INFO]   price_level                             	0.4208
# 2018-11-20 23:00:37,059 [INFO]   price_cost_effective                    	0.3439
# 2018-11-20 23:00:37,062 [INFO]   price_discount                          	0.4306
# 2018-11-20 23:00:37,069 [INFO]   environment_decoration                  	0.3431
# 2018-11-20 23:00:37,078 [INFO]   environment_noise                       	0.3080
# 2018-11-20 23:00:37,084 [INFO]   environment_space                       	0.3094
# 2018-11-20 23:00:37,087 [INFO]   environment_cleaness                    	0.3044
# 2018-11-20 23:00:37,090 [INFO]   dish_portion                            	0.2813
# 2018-11-20 23:00:37,092 [INFO]   dish_taste                              	0.3912
# 2018-11-20 23:00:37,095 [INFO]   dish_look                               	0.2561
# 2018-11-20 23:00:37,099 [INFO]   dish_recommendation                     	0.2804
# 2018-11-20 23:00:37,102 [INFO]   others_overall_experience               	0.3882
# 2018-11-20 23:00:37,104 [INFO]   others_willing_to_consume_again         	0.2908
# 2018-11-20 23:00:37,105 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:37,107 [INFO] 【lsa_100_sv -> LinearSVC】: 0.3321
# 2018-11-20 23:00:37,108 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:37,109 [INFO] Train for lsa_100_sv -> Logistic...
# 2018-11-20 23:00:45,099 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:00:45,102 [INFO]   location_traffic_convenience            	0.4163
# 2018-11-20 23:00:45,104 [INFO]   location_distance_from_business_district	0.2454
# 2018-11-20 23:00:45,107 [INFO]   location_easy_to_find                   	0.2748
# 2018-11-20 23:00:45,109 [INFO]   service_wait_time                       	0.2479
# 2018-11-20 23:00:45,112 [INFO]   service_waiters_attitude                	0.4935
# 2018-11-20 23:00:45,114 [INFO]   service_parking_convenience             	0.2831
# 2018-11-20 23:00:45,117 [INFO]   service_serving_speed                   	0.3487
# 2018-11-20 23:00:45,120 [INFO]   price_level                             	0.4287
# 2018-11-20 23:00:45,122 [INFO]   price_cost_effective                    	0.3424
# 2018-11-20 23:00:45,125 [INFO]   price_discount                          	0.4296
# 2018-11-20 23:00:45,128 [INFO]   environment_decoration                  	0.3438
# 2018-11-20 23:00:45,131 [INFO]   environment_noise                       	0.3012
# 2018-11-20 23:00:45,133 [INFO]   environment_space                       	0.3124
# 2018-11-20 23:00:45,136 [INFO]   environment_cleaness                    	0.3025
# 2018-11-20 23:00:45,139 [INFO]   dish_portion                            	0.2840
# 2018-11-20 23:00:45,142 [INFO]   dish_taste                              	0.4090
# 2018-11-20 23:00:45,145 [INFO]   dish_look                               	0.2588
# 2018-11-20 23:00:45,152 [INFO]   dish_recommendation                     	0.2790
# 2018-11-20 23:00:45,156 [INFO]   others_overall_experience               	0.3903
# 2018-11-20 23:00:45,161 [INFO]   others_willing_to_consume_again         	0.2907
# 2018-11-20 23:00:45,163 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:45,165 [INFO] 【lsa_100_sv -> Logistic】: 0.3341
# 2018-11-20 23:00:45,167 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:45,169 [INFO] Train for lsa_100_sv -> Ridge...
# 2018-11-20 23:00:47,829 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:00:47,833 [INFO]   location_traffic_convenience            	0.4148
# 2018-11-20 23:00:47,835 [INFO]   location_distance_from_business_district	0.2321
# 2018-11-20 23:00:47,838 [INFO]   location_easy_to_find                   	0.2587
# 2018-11-20 23:00:47,842 [INFO]   service_wait_time                       	0.2353
# 2018-11-20 23:00:47,845 [INFO]   service_waiters_attitude                	0.4452
# 2018-11-20 23:00:47,848 [INFO]   service_parking_convenience             	0.2482
# 2018-11-20 23:00:47,851 [INFO]   service_serving_speed                   	0.3175
# 2018-11-20 23:00:47,857 [INFO]   price_level                             	0.3789
# 2018-11-20 23:00:47,862 [INFO]   price_cost_effective                    	0.3325
# 2018-11-20 23:00:47,867 [INFO]   price_discount                          	0.4183
# 2018-11-20 23:00:47,871 [INFO]   environment_decoration                  	0.3431
# 2018-11-20 23:00:47,875 [INFO]   environment_noise                       	0.2950
# 2018-11-20 23:00:47,879 [INFO]   environment_space                       	0.2967
# 2018-11-20 23:00:47,884 [INFO]   environment_cleaness                    	0.3029
# 2018-11-20 23:00:47,888 [INFO]   dish_portion                            	0.2647
# 2018-11-20 23:00:47,898 [INFO]   dish_taste                              	0.3177
# 2018-11-20 23:00:47,910 [INFO]   dish_look                               	0.2444
# 2018-11-20 23:00:47,913 [INFO]   dish_recommendation                     	0.2659
# 2018-11-20 23:00:47,918 [INFO]   others_overall_experience               	0.3557
# 2018-11-20 23:00:47,924 [INFO]   others_willing_to_consume_again         	0.2867
# 2018-11-20 23:00:47,928 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:47,929 [INFO] 【lsa_100_sv -> Ridge】: 0.3127
# 2018-11-20 23:00:47,931 [INFO] ---------------------------------------------------
# 2018-11-20 23:00:47,932 [INFO] ======== Feature Model: lsa_500_sv =========
# 2018-11-20 23:00:47,934 [INFO] Train for lsa_500_sv -> LDA...
# 2018-11-20 23:01:17,127 [INFO] [Validate]: F1 Scores
# 2018-11-20 23:01:17,132 [INFO]   location_traffic_convenience            	0.4594
# 2018-11-20 23:01:17,137 [INFO]   location_distance_from_business_district	0.3319
# 2018-11-20 23:01:17,147 [INFO]   location_easy_to_find                   	0.3732
# 2018-11-20 23:01:17,155 [INFO]   service_wait_time                       	0.4114
# 2018-11-20 23:01:17,160 [INFO]   service_waiters_attitude                	0.5691
# 2018-11-20 23:01:17,164 [INFO]   service_parking_convenience             	0.4981
# 2018-11-20 23:01:17,169 [INFO]   service_serving_speed                   	0.5166
# 2018-11-20 23:01:17,174 [INFO]   price_level                             	0.5266
# 2018-11-20 23:01:17,177 [INFO]   price_cost_effective                    	0.4306
# 2018-11-20 23:01:17,179 [INFO]   price_discount                          	0.4849
# 2018-11-20 23:01:17,184 [INFO]   environment_decoration                  	0.4427
# 2018-11-20 23:01:17,191 [INFO]   environment_noise                       	0.5322
# 2018-11-20 23:01:17,196 [INFO]   environment_space                       	0.4565
# 2018-11-20 23:01:17,200 [INFO]   environment_cleaness                    	0.4753
# 2018-11-20 23:01:17,202 [INFO]   dish_portion                            	0.3761
# 2018-11-20 23:01:17,206 [INFO]   dish_taste                              	0.4928
# 2018-11-20 23:01:17,209 [INFO]   dish_look                               	0.3514
# 2018-11-20 23:01:17,211 [INFO]   dish_recommendation                     	0.3736
# 2018-11-20 23:01:17,214 [INFO]   others_overall_experience               	0.4461
# 2018-11-20 23:01:17,216 [INFO]   others_willing_to_consume_again         	0.3839
# 2018-11-20 23:01:17,217 [INFO] ---------------------------------------------------
# 2018-11-20 23:01:17,218 [INFO] 【lsa_500_sv -> LDA】: 0.4466
# 2018-11-20 23:01:17,219 [INFO] ---------------------------------------------------
# 2018-11-20 23:01:17,220 [INFO] Train for lsa_500_sv -> LinearSVC...
# 2018-11-20 23:01:47,237 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:01:47,242 [INFO]   location_traffic_convenience            	0.4317
# 2018-11-20 23:01:47,245 [INFO]   location_distance_from_business_district	0.3199
# 2018-11-20 23:01:47,248 [INFO]   location_easy_to_find                   	0.3425
# 2018-11-20 23:01:47,252 [INFO]   service_wait_time                       	0.3041
# 2018-11-20 23:01:47,258 [INFO]   service_waiters_attitude                	0.5411
# 2018-11-20 23:01:47,261 [INFO]   service_parking_convenience             	0.4118
# 2018-11-20 23:01:47,265 [INFO]   service_serving_speed                   	0.4627
# 2018-11-20 23:01:47,267 [INFO]   price_level                             	0.5025
# 2018-11-20 23:01:47,270 [INFO]   price_cost_effective                    	0.3824
# 2018-11-20 23:01:47,273 [INFO]   price_discount                          	0.4584
# 2018-11-20 23:01:47,277 [INFO]   environment_decoration                  	0.4162
# 2018-11-20 23:01:47,279 [INFO]   environment_noise                       	0.4366
# 2018-11-20 23:01:47,282 [INFO]   environment_space                       	0.3927
# 2018-11-20 23:01:47,285 [INFO]   environment_cleaness                    	0.4018
# 2018-11-20 23:01:47,288 [INFO]   dish_portion                            	0.3318
# 2018-11-20 23:01:47,290 [INFO]   dish_taste                              	0.4579
# 2018-11-20 23:01:47,293 [INFO]   dish_look                               	0.2892
# 2018-11-20 23:01:47,296 [INFO]   dish_recommendation                     	0.3221
# 2018-11-20 23:01:47,299 [INFO]   others_overall_experience               	0.4305
# 2018-11-20 23:01:47,301 [INFO]   others_willing_to_consume_again         	0.3246
# 2018-11-20 23:01:47,303 [INFO] ---------------------------------------------------
# 2018-11-20 23:01:47,304 [INFO] 【lsa_500_sv -> LinearSVC】: 0.3980
# 2018-11-20 23:01:47,305 [INFO] ---------------------------------------------------
# 2018-11-20 23:01:47,306 [INFO] Train for lsa_500_sv -> Logistic...
# 2018-11-20 23:02:12,731 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:02:12,735 [INFO]   location_traffic_convenience            	0.4247
# 2018-11-20 23:02:12,737 [INFO]   location_distance_from_business_district	0.3081
# 2018-11-20 23:02:12,740 [INFO]   location_easy_to_find                   	0.3296
# 2018-11-20 23:02:12,743 [INFO]   service_wait_time                       	0.2943
# 2018-11-20 23:02:12,746 [INFO]   service_waiters_attitude                	0.5442
# 2018-11-20 23:02:12,749 [INFO]   service_parking_convenience             	0.3439
# 2018-11-20 23:02:12,752 [INFO]   service_serving_speed                   	0.4335
# 2018-11-20 23:02:12,755 [INFO]   price_level                             	0.4857
# 2018-11-20 23:02:12,758 [INFO]   price_cost_effective                    	0.3557
# 2018-11-20 23:02:12,761 [INFO]   price_discount                          	0.4500
# 2018-11-20 23:02:12,764 [INFO]   environment_decoration                  	0.4053
# 2018-11-20 23:02:12,767 [INFO]   environment_noise                       	0.3676
# 2018-11-20 23:02:12,771 [INFO]   environment_space                       	0.3869
# 2018-11-20 23:02:12,775 [INFO]   environment_cleaness                    	0.3924
# 2018-11-20 23:02:12,778 [INFO]   dish_portion                            	0.3273
# 2018-11-20 23:02:12,782 [INFO]   dish_taste                              	0.4381
# 2018-11-20 23:02:12,785 [INFO]   dish_look                               	0.2842
# 2018-11-20 23:02:12,788 [INFO]   dish_recommendation                     	0.3101
# 2018-11-20 23:02:12,791 [INFO]   others_overall_experience               	0.4204
# 2018-11-20 23:02:12,794 [INFO]   others_willing_to_consume_again         	0.3348
# 2018-11-20 23:02:12,796 [INFO] ---------------------------------------------------
# 2018-11-20 23:02:12,797 [INFO] 【lsa_500_sv -> Logistic】: 0.3818
# 2018-11-20 23:02:12,798 [INFO] ---------------------------------------------------
# 2018-11-20 23:02:12,800 [INFO] Train for lsa_500_sv -> Ridge...
# 2018-11-20 23:02:31,690 [INFO] [Validate]: F1 Scores
# /Users/jesse/anaconda3/envs/idp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2018-11-20 23:02:31,693 [INFO]   location_traffic_convenience            	0.4244
# 2018-11-20 23:02:31,696 [INFO]   location_distance_from_business_district	0.3094
# 2018-11-20 23:02:31,698 [INFO]   location_easy_to_find                   	0.3397
# 2018-11-20 23:02:31,701 [INFO]   service_wait_time                       	0.2542
# 2018-11-20 23:02:31,703 [INFO]   service_waiters_attitude                	0.4752
# 2018-11-20 23:02:31,706 [INFO]   service_parking_convenience             	0.3556
# 2018-11-20 23:02:31,708 [INFO]   service_serving_speed                   	0.4370
# 2018-11-20 23:02:31,711 [INFO]   price_level                             	0.4401
# 2018-11-20 23:02:31,714 [INFO]   price_cost_effective                    	0.3307
# 2018-11-20 23:02:31,716 [INFO]   price_discount                          	0.4306
# 2018-11-20 23:02:31,719 [INFO]   environment_decoration                  	0.3880
# 2018-11-20 23:02:31,723 [INFO]   environment_noise                       	0.3733
# 2018-11-20 23:02:31,726 [INFO]   environment_space                       	0.3484
# 2018-11-20 23:02:31,730 [INFO]   environment_cleaness                    	0.3819
# 2018-11-20 23:02:31,735 [INFO]   dish_portion                            	0.2962
# 2018-11-20 23:02:31,738 [INFO]   dish_taste                              	0.3397
# 2018-11-20 23:02:31,741 [INFO]   dish_look                               	0.2691
# 2018-11-20 23:02:31,744 [INFO]   dish_recommendation                     	0.2805
# 2018-11-20 23:02:31,747 [INFO]   others_overall_experience               	0.3805
# 2018-11-20 23:02:31,749 [INFO]   others_willing_to_consume_again         	0.2963
# 2018-11-20 23:02:31,754 [INFO] ---------------------------------------------------
# 2018-11-20 23:02:31,755 [INFO] 【lsa_500_sv -> Ridge】: 0.3575
# 2018-11-20 23:02:31,757 [INFO] ---------------------------------------------------

# %%
rows = {}
for fm_name in all_scores:
    for clf_name in all_scores[fm_name]:
        key = f'{fm_name}.{clf_name}'
        rows[key] = [all_avg_scores[fm_name][clf_name],
                     *all_scores[fm_name][clf_name]]
df = pd.DataFrame(rows)
df.index = ['average', *y_train.columns]
df.T.sort_values('average', ascending=False)
# Out:
#                            average  location_traffic_convenience  \
# tfidf_sv_dense.LDA        0.459859                      0.466292
# lsa_1k.LDA                0.451776                      0.428954
# lsa_500_sv.LDA            0.446607                      0.459354
# tfidf_sv_dense.LinearSVC  0.421411                      0.442215
# lsa_200.LDA               0.408699                      0.440000
# lsa_1k.LinearSVC          0.398814                      0.428698
# lsa_500_sv.LinearSVC      0.398021                      0.431651
# tfidf_sv.ComplementNB     0.392122                      0.389630
# tfidf_sv_dense.Logistic   0.389897                      0.425154
# lsa_500_sv.Logistic       0.381847                      0.424717
# lsa_100_sv.LDA            0.372596                      0.420177
# tfidf_sv_dense.Ridge      0.362262                      0.413973
# lsa_500_sv.Ridge          0.357540                      0.424370
# lsa_1k.Ridge              0.356880                      0.422425
# lsa_200.LinearSVC         0.353405                      0.423445
# lsa_1k.Logistic           0.350713                      0.412069
# lsa_200.Ridge             0.334861                      0.417400
# lsa_100_sv.Logistic       0.334099                      0.416346
# lsa_100_sv.LinearSVC      0.332129                      0.422216
# lsa_200.Logistic          0.329735                      0.403552
# lsa_100_sv.Ridge          0.312713                      0.414833
# tfidf.ComplementNB        0.298397                      0.327004
# tfidf_sv.MultinomialNB    0.259409                      0.339084
# tfidf.DummyStratified     0.249552                      0.240357
# tfidf.MultinomialNB       0.228303                      0.235768
# tfidf.DummyMostFrequent   0.200041                      0.219164
#
#                           location_distance_from_business_district  \
# tfidf_sv_dense.LDA                                        0.340962
# lsa_1k.LDA                                                0.344891
# lsa_500_sv.LDA                                            0.331910
# tfidf_sv_dense.LinearSVC                                  0.336579
# lsa_200.LDA                                               0.303148
# lsa_1k.LinearSVC                                          0.332816
# lsa_500_sv.LinearSVC                                      0.319914
# tfidf_sv.ComplementNB                                     0.319275
# tfidf_sv_dense.Logistic                                   0.312505
# lsa_500_sv.Logistic                                       0.308133
# lsa_100_sv.LDA                                            0.267709
# tfidf_sv_dense.Ridge                                      0.296035
# lsa_500_sv.Ridge                                          0.309450
# lsa_1k.Ridge                                              0.317428
# lsa_200.LinearSVC                                         0.275383
# lsa_1k.Logistic                                           0.293323
# lsa_200.Ridge                                             0.265430
# lsa_100_sv.Logistic                                       0.245427
# lsa_100_sv.LinearSVC                                      0.239835
# lsa_200.Logistic                                          0.264684
# lsa_100_sv.Ridge                                          0.232075
# tfidf.ComplementNB                                        0.245082
# tfidf_sv.MultinomialNB                                    0.229305
# tfidf.DummyStratified                                     0.250182
# tfidf.MultinomialNB                                       0.222639
# tfidf.DummyMostFrequent                                   0.221789
#
#                           location_easy_to_find  service_wait_time  \
# tfidf_sv_dense.LDA                     0.410272           0.412732
# lsa_1k.LDA                             0.399770           0.415248
# lsa_500_sv.LDA                         0.373216           0.411363
# tfidf_sv_dense.LinearSVC               0.361738           0.379089
# lsa_200.LDA                            0.335515           0.343845
# lsa_1k.LinearSVC                       0.343540           0.324191
# lsa_500_sv.LinearSVC                   0.342465           0.304075
# tfidf_sv.ComplementNB                  0.319162           0.356397
# tfidf_sv_dense.Logistic                0.334288           0.295214
# lsa_500_sv.Logistic                    0.329628           0.294252
# lsa_100_sv.LDA                         0.295087           0.342691
# tfidf_sv_dense.Ridge                   0.321289           0.259971
# lsa_500_sv.Ridge                       0.339668           0.254156
# lsa_1k.Ridge                           0.328998           0.235388
# lsa_200.LinearSVC                      0.305048           0.285188
# lsa_1k.Logistic                        0.308907           0.265236
# lsa_200.Ridge                          0.289714           0.254100
# lsa_100_sv.Logistic                    0.274751           0.247877
# lsa_100_sv.LinearSVC                   0.269972           0.254106
# lsa_200.Logistic                       0.285934           0.248139
# lsa_100_sv.Ridge                       0.258688           0.235338
# tfidf.ComplementNB                     0.246090           0.254806
# tfidf_sv.MultinomialNB                 0.224368           0.235338
# tfidf.DummyStratified                  0.262276           0.245339
# tfidf.MultinomialNB                    0.220811           0.249854
# tfidf.DummyMostFrequent                0.216038           0.235338
#
#                           service_waiters_attitude  \
# tfidf_sv_dense.LDA                        0.572884
# lsa_1k.LDA                                0.563410
# lsa_500_sv.LDA                            0.569089
# tfidf_sv_dense.LinearSVC                  0.554437
# lsa_200.LDA                               0.543946
# lsa_1k.LinearSVC                          0.542338
# lsa_500_sv.LinearSVC                      0.541149
# tfidf_sv.ComplementNB                     0.459568
# tfidf_sv_dense.Logistic                   0.545828
# lsa_500_sv.Logistic                       0.544164
# lsa_100_sv.LDA                            0.497450
# tfidf_sv_dense.Ridge                      0.485147
# lsa_500_sv.Ridge                          0.475234
# lsa_1k.Ridge                              0.495315
# lsa_200.LinearSVC                         0.500793
# lsa_1k.Logistic                           0.506397
# lsa_200.Ridge                             0.476010
# lsa_100_sv.Logistic                       0.493529
# lsa_100_sv.LinearSVC                      0.487340
# lsa_200.Logistic                          0.493434
# lsa_100_sv.Ridge                          0.445166
# tfidf.ComplementNB                        0.468664
# tfidf_sv.MultinomialNB                    0.439007
# tfidf.DummyStratified                     0.243789
# tfidf.MultinomialNB                       0.338680
# tfidf.DummyMostFrequent                   0.144785
#
#                           service_parking_convenience  service_serving_speed  \
# tfidf_sv_dense.LDA                           0.515427               0.530130
# lsa_1k.LDA                                   0.475317               0.498066
# lsa_500_sv.LDA                               0.498109               0.516629
# tfidf_sv_dense.LinearSVC                     0.411494               0.483994
# lsa_200.LDA                                  0.513407               0.427153
# lsa_1k.LinearSVC                             0.357451               0.442308
# lsa_500_sv.LinearSVC                         0.411760               0.462675
# tfidf_sv.ComplementNB                        0.283975               0.425481
# tfidf_sv_dense.Logistic                      0.346813               0.429196
# lsa_500_sv.Logistic                          0.343861               0.433497
# lsa_100_sv.LDA                               0.359270               0.411756
# tfidf_sv_dense.Ridge                         0.351529               0.405159
# lsa_500_sv.Ridge                             0.355613               0.436971
# lsa_1k.Ridge                                 0.321036               0.414936
# lsa_200.LinearSVC                            0.349425               0.371785
# lsa_1k.Logistic                              0.286274               0.359088
# lsa_200.Ridge                                0.297309               0.345109
# lsa_100_sv.Logistic                          0.283054               0.348660
# lsa_100_sv.LinearSVC                         0.281913               0.339021
# lsa_200.Logistic                             0.272454               0.325535
# lsa_100_sv.Ridge                             0.248161               0.317453
# tfidf.ComplementNB                           0.241896               0.236881
# tfidf_sv.MultinomialNB                       0.242158               0.246976
# tfidf.DummyStratified                        0.248240               0.241503
# tfidf.MultinomialNB                          0.241896               0.228261
# tfidf.DummyMostFrequent                      0.242109               0.228497
#
#                           price_level  price_cost_effective  \
# tfidf_sv_dense.LDA           0.548450              0.455290
# lsa_1k.LDA                   0.537697              0.456815
# lsa_500_sv.LDA               0.526618              0.430554
# tfidf_sv_dense.LinearSVC     0.527506              0.383646
# lsa_200.LDA                  0.485807              0.400839
# lsa_1k.LinearSVC             0.530034              0.368271
# lsa_500_sv.LinearSVC         0.502496              0.382424
# tfidf_sv.ComplementNB        0.490206              0.409127
# tfidf_sv_dense.Logistic      0.504688              0.356294
# lsa_500_sv.Logistic          0.485729              0.355709
# lsa_100_sv.LDA               0.450329              0.399549
# tfidf_sv_dense.Ridge         0.457400              0.331079
# lsa_500_sv.Ridge             0.440148              0.330733
# lsa_1k.Ridge                 0.491858              0.348738
# lsa_200.LinearSVC            0.457516              0.332855
# lsa_1k.Logistic              0.462793              0.331677
# lsa_200.Ridge                0.411172              0.326446
# lsa_100_sv.Logistic          0.428660              0.342415
# lsa_100_sv.LinearSVC         0.420832              0.343897
# lsa_200.Logistic             0.402942              0.312812
# lsa_100_sv.Ridge             0.378950              0.332472
# tfidf.ComplementNB           0.409466              0.250684
# tfidf_sv.MultinomialNB       0.240122              0.231296
# tfidf.DummyStratified        0.259458              0.248138
# tfidf.MultinomialNB          0.180843              0.215521
# tfidf.DummyMostFrequent      0.165238              0.215780
#
#                                        ...                 \
# tfidf_sv_dense.LDA                     ...
# lsa_1k.LDA                             ...
# lsa_500_sv.LDA                         ...
# tfidf_sv_dense.LinearSVC               ...
# lsa_200.LDA                            ...
# lsa_1k.LinearSVC                       ...
# lsa_500_sv.LinearSVC                   ...
# tfidf_sv.ComplementNB                  ...
# tfidf_sv_dense.Logistic                ...
# lsa_500_sv.Logistic                    ...
# lsa_100_sv.LDA                         ...
# tfidf_sv_dense.Ridge                   ...
# lsa_500_sv.Ridge                       ...
# lsa_1k.Ridge                           ...
# lsa_200.LinearSVC                      ...
# lsa_1k.Logistic                        ...
# lsa_200.Ridge                          ...
# lsa_100_sv.Logistic                    ...
# lsa_100_sv.LinearSVC                   ...
# lsa_200.Logistic                       ...
# lsa_100_sv.Ridge                       ...
# tfidf.ComplementNB                     ...
# tfidf_sv.MultinomialNB                 ...
# tfidf.DummyStratified                  ...
# tfidf.MultinomialNB                    ...
# tfidf.DummyMostFrequent                ...
#
#                           environment_decoration  environment_noise  \
# tfidf_sv_dense.LDA                      0.458143           0.572426
# lsa_1k.LDA                              0.454947           0.544886
# lsa_500_sv.LDA                          0.442681           0.532172
# tfidf_sv_dense.LinearSVC                0.451426           0.506178
# lsa_200.LDA                             0.396346           0.401883
# lsa_1k.LinearSVC                        0.426472           0.448942
# lsa_500_sv.LinearSVC                    0.416187           0.436649
# tfidf_sv.ComplementNB                   0.382232           0.437925
# tfidf_sv_dense.Logistic                 0.417671           0.405237
# lsa_500_sv.Logistic                     0.405342           0.367622
# lsa_100_sv.LDA                          0.352048           0.332257
# tfidf_sv_dense.Ridge                    0.387738           0.468640
# lsa_500_sv.Ridge                        0.387968           0.373323
# lsa_1k.Ridge                            0.400482           0.385663
# lsa_200.LinearSVC                       0.362381           0.328616
# lsa_1k.Logistic                         0.387820           0.342480
# lsa_200.Ridge                           0.361886           0.324078
# lsa_100_sv.Logistic                     0.343815           0.301236
# lsa_100_sv.LinearSVC                    0.343078           0.308039
# lsa_200.Logistic                        0.361388           0.310838
# lsa_100_sv.Ridge                        0.343074           0.295045
# tfidf.ComplementNB                      0.346797           0.260574
# tfidf_sv.MultinomialNB                  0.331504           0.224052
# tfidf.DummyStratified                   0.251946           0.258898
# tfidf.MultinomialNB                     0.311022           0.209691
# tfidf.DummyMostFrequent                 0.167465           0.203440
#
#                           environment_space  environment_cleaness  \
# tfidf_sv_dense.LDA                 0.498306              0.484644
# lsa_1k.LDA                         0.477421              0.478036
# lsa_500_sv.LDA                     0.456488              0.475279
# tfidf_sv_dense.LinearSVC           0.470011              0.417699
# lsa_200.LDA                        0.397675              0.398892
# lsa_1k.LinearSVC                   0.407851              0.407844
# lsa_500_sv.LinearSVC               0.392652              0.401811
# tfidf_sv.ComplementNB              0.442779              0.382203
# tfidf_sv_dense.Logistic            0.420750              0.396754
# lsa_500_sv.Logistic                0.386928              0.392433
# lsa_100_sv.LDA                     0.361546              0.339294
# tfidf_sv_dense.Ridge               0.379530              0.376269
# lsa_500_sv.Ridge                   0.348414              0.381889
# lsa_1k.Ridge                       0.371180              0.380989
# lsa_200.LinearSVC                  0.329240              0.357296
# lsa_1k.Logistic                    0.347020              0.367801
# lsa_200.Ridge                      0.312571              0.352185
# lsa_100_sv.Logistic                0.312395              0.302506
# lsa_100_sv.LinearSVC               0.309405              0.304381
# lsa_200.Logistic                   0.305931              0.338273
# lsa_100_sv.Ridge                   0.296701              0.302909
# tfidf.ComplementNB                 0.283469              0.285896
# tfidf_sv.MultinomialNB             0.217153              0.220451
# tfidf.DummyStratified              0.245395              0.259457
# tfidf.MultinomialNB                0.197270              0.200761
# tfidf.DummyMostFrequent            0.190517              0.191206
#
#                           dish_portion  dish_taste  dish_look  \
# tfidf_sv_dense.LDA            0.370326    0.483179   0.367013
# lsa_1k.LDA                    0.385640    0.514141   0.342406
# lsa_500_sv.LDA                0.376105    0.492761   0.351356
# tfidf_sv_dense.LinearSVC      0.343321    0.465163   0.305578
# lsa_200.LDA                   0.339981    0.494261   0.310214
# lsa_1k.LinearSVC              0.345914    0.444789   0.296249
# lsa_500_sv.LinearSVC          0.331832    0.457851   0.289214
# tfidf_sv.ComplementNB         0.357981    0.480247   0.349911
# tfidf_sv_dense.Logistic       0.339340    0.450403   0.293099
# lsa_500_sv.Logistic           0.327336    0.438108   0.284163
# lsa_100_sv.LDA                0.318046    0.467102   0.281788
# tfidf_sv_dense.Ridge          0.277650    0.349550   0.275427
# lsa_500_sv.Ridge              0.296241    0.339664   0.269108
# lsa_1k.Ridge                  0.271356    0.337177   0.248031
# lsa_200.LinearSVC             0.292804    0.380651   0.261665
# lsa_1k.Logistic               0.299476    0.370579   0.269778
# lsa_200.Ridge                 0.286272    0.344416   0.237213
# lsa_100_sv.Logistic           0.283978    0.409032   0.258769
# lsa_100_sv.LinearSVC          0.281252    0.391228   0.256062
# lsa_200.Logistic              0.280126    0.357891   0.255808
# lsa_100_sv.Ridge              0.264720    0.317736   0.244377
# tfidf.ComplementNB            0.277620    0.349748   0.238653
# tfidf_sv.MultinomialNB        0.204276    0.323848   0.212839
# tfidf.DummyStratified         0.253761    0.243610   0.244121
# tfidf.MultinomialNB           0.177798    0.283342   0.209640
# tfidf.DummyMostFrequent       0.174394    0.172346   0.209909
#
#                           dish_recommendation  others_overall_experience  \
# tfidf_sv_dense.LDA                   0.367459                   0.470756
# lsa_1k.LDA                           0.358052                   0.463108
# lsa_500_sv.LDA                       0.373592                   0.446095
# tfidf_sv_dense.LinearSVC             0.325279                   0.443375
# lsa_200.LDA                          0.346392                   0.442764
# lsa_1k.LinearSVC                     0.312868                   0.433277
# lsa_500_sv.LinearSVC                 0.322134                   0.430498
# tfidf_sv.ComplementNB                0.302559                   0.423626
# tfidf_sv_dense.Logistic              0.314696                   0.427298
# lsa_500_sv.Logistic                  0.310072                   0.420445
# lsa_100_sv.LDA                       0.343939                   0.415595
# tfidf_sv_dense.Ridge                 0.280327                   0.392487
# lsa_500_sv.Ridge                     0.280527                   0.380487
# lsa_1k.Ridge                         0.293080                   0.350250
# lsa_200.LinearSVC                    0.286094                   0.414378
# lsa_1k.Logistic                      0.279369                   0.389591
# lsa_200.Ridge                        0.275527                   0.382432
# lsa_100_sv.Logistic                  0.278953                   0.390289
# lsa_100_sv.LinearSVC                 0.280401                   0.388222
# lsa_200.Logistic                     0.270827                   0.379766
# lsa_100_sv.Ridge                     0.265850                   0.355696
# tfidf.ComplementNB                   0.227108                   0.362564
# tfidf_sv.MultinomialNB               0.223329                   0.264945
# tfidf.DummyStratified                0.250343                   0.258173
# tfidf.MultinomialNB                  0.223084                   0.199158
# tfidf.DummyMostFrequent              0.223329                   0.199447
#
#                           others_willing_to_consume_again
# tfidf_sv_dense.LDA                               0.383674
# lsa_1k.LDA                                       0.402531
# lsa_500_sv.LDA                                   0.383864
# tfidf_sv_dense.LinearSVC                         0.349842
# lsa_200.LDA                                      0.371712
# lsa_1k.LinearSVC                                 0.318851
# lsa_500_sv.LinearSVC                             0.324592
# tfidf_sv.ComplementNB                            0.359624
# tfidf_sv_dense.Logistic                          0.328747
# lsa_500_sv.Logistic                              0.334840
# lsa_100_sv.LDA                                   0.353258
# tfidf_sv_dense.Ridge                             0.299881
# lsa_500_sv.Ridge                                 0.296250
# lsa_1k.Ridge                                     0.279978
# lsa_200.LinearSVC                                0.305369
# lsa_1k.Logistic                                  0.296447
# lsa_200.Ridge                                    0.298006
# lsa_100_sv.Logistic                              0.290668
# lsa_100_sv.LinearSVC                             0.290798
# lsa_200.Logistic                                 0.292376
# lsa_100_sv.Ridge                                 0.286729
# tfidf.ComplementNB                               0.261413
# tfidf_sv.MultinomialNB                           0.210725
# tfidf.DummyStratified                            0.245025
# tfidf.MultinomialNB                              0.195655
# tfidf.DummyMostFrequent                          0.190671
#
# [26 rows x 21 columns]

# %% [markdown]
# ## Conclusion
#
# - `ComplementNB` performs much better than a simple MultinomialNB, because our class labels are mostly unbalanced.
# - `LatentDirichletAllocation` topics as features are not suitable for our classification problem, as features are often collinear. They often fare no better than the dummy classifier where we simply return the most frequent labels.
# - LSA (Latent Semantic Analysis) shows a much more promising outcome, especially when combined with Linear Discriminant Analysis or SVC.
# - A smaller vocabulary had marginal impact on the performance, what matters more is the number of SVD components in LSA. The higher the better, as more compoents will capture more information. LDA and SVC both perform well in high dimensional space.
# - Basically SVD makes each feature (component) more indendent with each other, making LDA and SVC easier to come up with good fittings.
# - Tree based models are not particularly useful. But the results may be different had we tuned the tree structure more.
#
# ## Next Steps
#
# Required:
#
# - Tune hyperparamters for `ComplementNB`, `TruncatedSVD`, `LinearDiscriminantAnalysis` and `SVC`/`LinearSVC`. Try different kernel functions.
# - Test some boosting methods, especially [xgboost](https://xgboost.readthedocs.io/en/latest/).
# - Test word embedding as features.
#
# Optional:
#
# - Possibly use different classifier for different labels.
# - Test two step predictions: first run binary prediction for "mentioned" vs "not mentioned", i.e., -2 vs (-1, 0, 1), then predict (-1, 0, 1).
#     - This could happen as either [ClassifierChain](https://scikit-learn.org/stable/modules/multiclass.html#classifierchain) or separate steps.
